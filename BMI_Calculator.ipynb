# %%
# This is calculator for find the body mass index...
# BMI = (weight * 703) / (height * height)...

print("BMI Calculator !!!")

Name = input("Enter your name: ")
Age = int(input("Enter your age: "))
Weight = float(input("Enter your weight in pounds: "))
Height = float(input("Enter your height in inches: "))
BMI = (Weight * 703) / (Height * Height)
print("This is your body mass index: ",BMI)

if BMI > 0:
    if BMI < 18.5:
        print(Name ,"you are underweight")
    elif BMI <= 24.9:
        print(Name ,"you are normal weight")
    elif BMI <= 29.9:
        print(Name ,"you are overweight")
    elif BMI <= 34.9:
        print(Name ,"you are obese")
    elif BMI <= 39.9:
        print(Name ,"you are severly obese")
    else:
        print(Name ,"you are mobidly obese")
else:
    print(Name ,"please enter a valid value")
# Out:
# BMI Calculator !!!
# Enter your name:  Alex
# Enter your age:  27
# Enter your weight in pounds:  180
# Enter your height in inches:  5.8
# This is your body mass index:  3761.593341260404
# Alex you are mobidly obese
